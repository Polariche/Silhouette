# %%
import torch
import numpy as np

import matplotlib.pyplot as plt
from tqdm.notebook import tqdm as tqdm
import os, imageio

# %%
image_url = 'https://live.staticflickr.com/7492/15677707699_d9d67acf9d_b.jpg'
img = imageio.imread(image_url)[..., :3] / 255.
c = [img.shape[0]//2, img.shape[1]//2]
r = 256
img = img[c[0]-r:c[0]+r, c[1]-r:c[1]+r]


plt.imshow(img)
plt.show()

# %%
coords = np.linspace(0, 1, img.shape[0], endpoint=False)
x_test = np.stack(np.meshgrid(coords, coords), -1)
test_data = [x_test, img]
train_data = [x_test[::2,::2], img[::2,::2]]

# %%
device = torch.device('cuda')

# %%
test_coord = torch.from_numpy(x_test).to(device)
# Out:
# THCudaCheck FAIL file=/opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_18414/4191193898.py in <module>
# ----> 1 test_coord = torch.from_numpy(x_test).to(device)
#
# /opt/conda/lib/python3.7/site-packages/torch/cuda/__init__.py in _lazy_init()
#     151             raise AssertionError(
#     152                 "libcudart functions unavailable. It looks like you have a broken build?")
# --> 153         torch._C._cuda_init()
#     154         # Some of the queued calls may reentrantly call _lazy_init();
#     155         # we need to just return without initializing in that case.
#
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/THC/THCGeneral.cpp:47
